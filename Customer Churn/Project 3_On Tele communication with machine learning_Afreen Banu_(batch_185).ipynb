# %% [markdown]
# #                    Telecommunication Case Study

# %% [markdown]
# ### Business Understanding
# - The telecommunications sector has become one of the main industries in developed countries. The technical progress and the increasing number of operators raised the level of competition. Companies are working hard to survive in this competitive market depending on multiple strategies. Three main strategies have been proposed to generate more revenues:
# 1. Acquire new customers
# 2. Upsell the existing customers
# 3. Increase the retention period of customers
# - However, comparing these strategies taking the value of return on investment (RoI) of each into account has shown that the third strategy is the most profitable strategy, proving that retaining an existing customer costs much lower than acquiring a new one, in addition to being considered much easier than the upselling strategy. To apply the third strategy, companies have to decrease the potential of customer’s churn, known as "the customer movement from one provider to another".
#
# - Customer churn is a considerable concern in service sectors with high competitive services. On the other hand, predicting the customers who are likely to leave the company will represent a potentially large additional revenue source if it is done in the early phase.
#
# - Many research confirmed that machine learning technology is highly efficient to predict this situation. This technique is applied through learning from previous data.
#
# - Customer Churn is one of the most important and challenging problems for businesses such as Credit Card companies, cable service providers, SASS and telecommunication companies worldwide. Even though it is not the most fun to look at, customer churn metrics can help businesses improve customer retention.

# %% [markdown]
# ### Problem Statement:
# - Given various features about a customer like Gender, SeniorCitizen, Partner, Dependents etc.. .
# - The aim here is to predict whether the customer will churn or not.

# %% [markdown]
# ### Churn_Dataset

# %% [markdown]
# #### Import the required Libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell'

# %% [markdown]
# ### Steps to be followed
# #### Step - 1: Load the data and perform the basic EDA to understand the data.

# %%
a = pd.read_csv('C://Users//dell//Downloads//churn_dataset.csv')
a
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### The data set includes information about:
#
# - Customers who left within the last month – the column is called Churn
# - Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
# - Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
# - Demographic info about customers – gender, age range, and if they have partners and dependents

# %%
a.shape
# Out:
# (7043, 21)

# %%
a.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
a.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
a.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
a.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
a.value_counts('Churn')
# Out:
# Churn
# No     5174
# Yes    1869
# dtype: int64

# %%
a.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
a.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
a.mean().to_frame().T
# Out:
#    SeniorCitizen     tenure  MonthlyCharges
# 0       0.162147  32.371149       64.761692

# %%
a.median().to_frame().T
# Out:
#    SeniorCitizen  tenure  MonthlyCharges
# 0            0.0    29.0           70.35

# %%
a.std().to_frame().T
# Out:
#    SeniorCitizen     tenure  MonthlyCharges
# 0       0.368612  24.559481       30.090047

# %%
a.skew().to_frame().T
# Out:
#    SeniorCitizen   tenure  MonthlyCharges
# 0       1.833633  0.23954       -0.220524

# %%
a.var().to_frame().T
# Out:
#    SeniorCitizen      tenure  MonthlyCharges
# 0       0.135875  603.168108      905.410934

# %%
num = a.select_dtypes(include = 'number').columns
num
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')

# %%
cat = a.select_dtypes(exclude = 'number').columns
cat
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
a['SeniorCitizen'].describe()
# Out:
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64

# %% [markdown]
# ### Detection of outliers

# %%
for i in num:
    plt.figure(figsize=(15,1))
    sns.boxplot(a[i])
    plt.show()

# %% [markdown]
# ### Inter Quartile Range(IQR):
# - Inter Quartile Range : iqr = q3-q1
#
# - lb = q1 - 1.5*iqr
#
# - ub = q3 - 1.5*iqr
#
# #### Removal of Outliers using IQR

# %%
q1 = a['SeniorCitizen'].quantile(0.25)
q3 = a['SeniorCitizen'].quantile(0.75)

iqr = q3 - q1
lb = q1 - (1.5*iqr)

ub = q3 + (1.5*iqr)


Outliers = a[(a['SeniorCitizen'] < lb) | (a['SeniorCitizen'] > ub)].index
Outliers

# %%
a.drop(Outliers,inplace= True)

# %%
for i in num:
    plt.figure(figsize=(15,1))
    sns.boxplot(a[i])
    plt.show()

# %%
a.shape
# Out:
# (5901, 21)

# %%
a['TotalCharges'] = a['TotalCharges'].replace(' ',np.nan)
a['TotalCharges'] = a['TotalCharges'].astype(float)

# %%
a['TotalCharges'].isna().sum()
# Out:
# 11

# %%
a['TotalCharges'] =a['TotalCharges'].fillna(a['TotalCharges'].mean())

# %%
a.drop(['customerID'],axis =1,inplace = True)

# %%
a.to_csv('C://Users//dell//Downloads//churn_dataset.csv')

# %%
a = pd.read_csv('C://Users//dell//Downloads//churn_dataset.csv')
a.drop(['Unnamed: 0'],axis =1,inplace = True)
a.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ### Exploratory Data Analysis
# - Univariate Analysis
# - Bivariate Analysis
# - Missing Values
# - Outliers

# %% [markdown]
# ### Univariant Analysis
# #### Numerical

# %%
num = a.select_dtypes(include = 'number').columns
num
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
sns.histplot(a['tenure'],bins = 10, edgecolor = 'black',kde = True)
plt.show()

# %% [markdown]
# ### Observation: This plot shows that 'tenure' has more count for below  10 tenure.

# %%
sns.displot(a['MonthlyCharges'],kde = True,bins=[0,5,10,15,20,25,30,40,60,80])
plt.title('Histogram of MonthlyCharges')
plt.show()

# %% [markdown]
# ### Observation": From above dist plot we observe that 'MonthlyCharges' has more count at 60-80.

# %% [markdown]
# #### Categorical

# %%
cat = a.select_dtypes(exclude = 'number').columns
cat
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
sns.displot(a['InternetService'],kind= 'hist',color = 'green')
plt.show()

# %% [markdown]
# ### Observation: This graph represent that 'InternetService' has maximum count on Fibre optic.

# %%
sns.countplot(x = 'PaymentMethod',data = a)
plt.title('Data collection of PaymentMethod')
plt.xlabel('Name of PaymentMethod')

plt.xticks(rotation = 90)
plt.yticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Observation: From this bar graph we observe that less count of  PaymentMethod at Bank transfer(automatic).

# %% [markdown]
# ### Bivariate Analysis
# #### Numerical-Numerical

# %%
plt.scatter(a['TotalCharges'],a['MonthlyCharges'])
plt.xlabel('Different tenure')
plt.ylabel('MonthlyCharges')
plt.show()

# %%
a.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen             NaN       NaN             NaN           NaN
# tenure                    NaN  1.000000        0.248766      0.813263
# MonthlyCharges            NaN  0.248766        1.000000      0.661792
# TotalCharges              NaN  0.813263        0.661792      1.000000

# %%
cor = a.corr()
sns.heatmap(cor,annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observation: There is a negative correlation between tenure and MonthlyCharges.

# %% [markdown]
# #### Numerical- Categorical

# %%
sns.violinplot(x= a['MultipleLines'],y= a['MonthlyCharges'],data = a)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation: From this violin plot we can observe that Multiplelines of 'NO' has more Monthlycharges.

# %%
plt.figure(figsize =(10,5))
sns.barplot(x = 'PaymentMethod',y = 'MonthlyCharges', data = a)
plt.title("Bar-chart of children from different PaymentMethod ")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Obseravtion: This plot represents that PayementMethod of 'Mailed Check' has low MonthlyCharges.

# %% [markdown]
# #### Categorical-Categorical

# %%
crosstab = pd.crosstab(a['InternetService'],a['PhoneService'])
plt.figure(figsize =(20,15))
plt.figure(figsize = (15,8))
crosstab.plot(kind = 'bar',stacked = True)
plt.show()

# %% [markdown]
# ### Observation: InternetService of 'Fibre optic' has only 'Yes' PhoneService.

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data = a,hue = 'Churn')

# %%
plt.figure(figsize=(200,125))
sns.catplot(x = 'Contract',y = 'tenure',data = a, kind = 'bar')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Observation: This plot shows that Contract of 'Two year'has more count of tenure.

# %% [markdown]
# ### Step - 2: Document the below mentioned points properly:
# - Identify the input and output/target variables.
# - Identify the type of ML Task.
# - Identify the Evaluation Metric.
# - For regression task - Mean Absolute Error
# - For classification task - Accuracy

# %%
y = a['Churn']
X = a[['gender','SeniorCitizen','Partner','Dependents','tenure','PhoneService','MultipleLines',
       'InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies',
       'Contract','PaperlessBilling','PaymentMethod','MonthlyCharges','TotalCharges']]

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: object

# %% [markdown]
# ### Step - 3: Split the dataset into Training and Testing (recommended 75:25 split).

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.75, random_state = 100)

print(X_train.shape,y_train.shape)

print(X_test.shape,y_test.shape)
# Out:
# (4425, 19) (4425,)
# (1476, 19) (1476,)

# %%
X_train.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %% [markdown]
# ### Step - 4: Data preparation on train data:
# - For Numerical Variables - Standardization or Normalization (Fit and Transform)
# - For Categorical - LabelEncoding or OneHotEncoding (Choose wisely)

# %% [markdown]
# ### Separation of Categorical & Numerical feature on X_train data

# %%
X_train_num = X_train.select_dtypes(include=['int64','float64'])
X_train_num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 4764              0       2           45.15         98.50
# 4503              0      17           94.40       1617.50
# 6281              0       6           20.60        116.60
# 859               0      72           64.80       4719.75
# 5916              0      72          112.75       8192.60
# ...             ...     ...             ...           ...
# 2244              0      34           64.40       2088.75
# 423               0      44           25.70       1110.50
# 93                0      65          111.05       7107.00
# 4662              0      22           20.15        432.50
# 6731              0      24           19.55        470.20
#
# [4425 rows x 4 columns]

# %%
X_train_cat = X_train.select_dtypes(include = ['object'])
X_train_cat
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 4764    Male      No         No          Yes                No
# 4503  Female      No         No          Yes               Yes
# 6281    Male      No         No          Yes                No
# 859     Male     Yes        Yes           No  No phone service
# 5916  Female      No         No          Yes               Yes
# ...      ...     ...        ...          ...               ...
# 2244  Female      No         No          Yes               Yes
# 423     Male     Yes        Yes          Yes               Yes
# 93    Female      No         No          Yes               Yes
# 4662    Male      No        Yes          Yes                No
# 6731  Female      No         No          Yes                No
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 4764             DSL                   No                   No
# 4503     Fiber optic                  Yes                  Yes
# ...

# %% [markdown]
# ### Scaling the numerical features on X_train

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num),
                                   columns = X_train_num.columns,
                                   index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 4764            0.0 -1.215630       -0.546851     -0.928761
# 4503            0.0 -0.608136        1.081306     -0.247818
# 6281            0.0 -1.053632       -1.358450     -0.920647
# 859             0.0  1.619346        0.102759      1.142868
# 5916            0.0  1.619346        1.687939      2.699688

# %%
X_train_num_rescaled.describe()
# Out:
#        SeniorCitizen        tenure  MonthlyCharges  TotalCharges
# count         4425.0  4.425000e+03    4.425000e+03  4.425000e+03
# mean             0.0 -2.508979e-18    3.914007e-18 -5.346633e-17
# std              0.0  1.000113e+00    1.000113e+00  1.000113e+00
# min              0.0 -1.296630e+00   -1.436138e+00 -9.644888e-01
# 25%              0.0 -9.726325e-01   -1.194807e+00 -8.165553e-01
# 50%              0.0 -1.626393e-01    1.308592e-01 -4.010417e-01
# 75%              0.0  9.308515e-01    8.184868e-01  6.259302e-01
# max              0.0  1.619346e+00    1.886293e+00  2.920333e+00

# %% [markdown]
# ### Applying OneHotEncoding on Categorical Columns on X_train

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(drop ='first', sparse = False)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat),
                              columns = encoder.get_feature_names_out(X_train_cat.columns),
                              index = X_train_cat.index) 

X_train_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4764          1.0          0.0             0.0               1.0
# 4503          0.0          0.0             0.0               1.0
# 6281          1.0          0.0             0.0               1.0
# 859           1.0          1.0             1.0               0.0
# 5916          0.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 4764                             0.0                0.0
# 4503                             0.0                1.0
# 6281                             0.0                0.0
# 859                              1.0                0.0
# 5916                             0.0                1.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 4764                          0.0                 0.0
# 4503                          1.0                 0.0
# 6281                          0.0                 1.0
# ...

# %%
X_train_cat_ohe.describe()
# Out:
#        gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# count  4425.000000  4425.000000     4425.000000       4425.000000
# mean      0.505763     0.478418        0.344181          0.904181
# std       0.500023     0.499590        0.475154          0.294376
# min       0.000000     0.000000        0.000000          0.000000
# 25%       0.000000     0.000000        0.000000          1.000000
# 50%       1.000000     0.000000        0.000000          1.000000
# 75%       1.000000     1.000000        1.000000          1.000000
# max       1.000000     1.000000        1.000000          1.000000
#
#        MultipleLines_No phone service  MultipleLines_Yes  \
# count                     4425.000000        4425.000000
# mean                         0.095819           0.386893
# std                          0.294376           0.487094
# min                          0.000000           0.000000
# 25%                          0.000000           0.000000
# ...

# %% [markdown]
# ### Concatinating the Encoded Categorical Features and Rescaled Numerical Features for X_train

# %%
X_train_transformed = pd.concat([X_train_num_rescaled,X_train_cat_ohe],axis = 1)

X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 4764            0.0 -1.215630       -0.546851     -0.928761          1.0
# 4503            0.0 -0.608136        1.081306     -0.247818          0.0
# 6281            0.0 -1.053632       -1.358450     -0.920647          1.0
# 859             0.0  1.619346        0.102759      1.142868          1.0
# 5916            0.0  1.619346        1.687939      2.699688          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4764          0.0             0.0               1.0
# 4503          0.0             0.0               1.0
# 6281          0.0             0.0               1.0
# 859           1.0             1.0               0.0
# 5916          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 4764                             0.0                0.0  ...
# 4503                             0.0                1.0  ...
# ...

# %% [markdown]
# ### Step - 5: Data preparation on test data:
# - For Numerical Variables - Standardization (Transform)
# - For Categorical - LabelEncoding or OneHotEncoding (Choose wisely)

# %% [markdown]
# ### Separation of Categorical & Numerical feature on X_test data

# %%
X_test_cat = X_test.select_dtypes(include = ['object'])

X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 2816  Female     Yes         No          Yes           Yes     Fiber optic
# 1321    Male     Yes        Yes          Yes            No             DSL
# 1455  Female     Yes         No          Yes           Yes     Fiber optic
# 6526    Male      No        Yes          Yes           Yes     Fiber optic
# 2227    Male     Yes        Yes          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 2816                  Yes                  Yes                  Yes
# 1321                  Yes                  Yes                  Yes
# 1455                  Yes                  Yes                  Yes
# 6526                   No                   No                   No
# 2227  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  Contract  \
# ...

# %%
X_test_cat.describe()
# Out:
#        gender Partner Dependents PhoneService MultipleLines InternetService  \
# count    1476    1476       1476         1476          1476            1476
# unique      2       2          2            2             3               3
# top      Male      No         No          Yes            No     Fiber optic
# freq      743     764        980         1322           728             570
#
#        OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# count            1476         1476             1476        1476        1476
# unique              3            3                3           3           3
# top                No           No               No          No         Yes
# freq              667          607              625         661         560
#
#        StreamingMovies        Contract PaperlessBilling     PaymentMethod
# count             1476            1476             1476              1476
# ...

# %%
X_test_num = X_test.select_dtypes(include=['int64','float64'])

X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 2816              0      72          109.55       8165.10
# 1321              0      60           65.85       3928.30
# 1455              0      36          106.05       3834.40
# 6526              0      49          100.60       5069.65
# 2227              0      58           19.55       1108.80

# %%
X_test_num.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count         1476.0  1476.000000     1476.000000   1476.000000
# mean             0.0    32.720867       62.314499   2213.385717
# std              0.0    24.431253       30.511715   2232.029104
# min              0.0     0.000000       18.750000     18.900000
# 25%              0.0     9.000000       25.650000    414.737500
# 50%              0.0    30.000000       66.375000   1351.650000
# 75%              0.0    55.000000       87.862500   3548.437500
# max              0.0    72.000000      117.150000   8529.500000

# %% [markdown]
# ### Scaling the numerical features on X_test

# %%
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num),
                                   columns = X_test_num.columns,
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 2816            0.0  1.619346        1.582150      2.687360
# 1321            0.0  1.133350        0.137471      0.788074
# 1455            0.0  0.161358        1.466444      0.745980
# 6526            0.0  0.687854        1.286272      1.299722
# 2227            0.0  1.052350       -1.393162     -0.475860

# %%
X_test_num_rescaled.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count         1476.0  1476.000000     1476.000000   1476.000000
# mean             0.0     0.028554        0.020591      0.019307
# std              0.0     0.989457        1.008687      1.000581
# min              0.0    -1.296630       -1.419609     -0.964444
# 25%              0.0    -0.932133       -1.191502     -0.786997
# 50%              0.0    -0.081640        0.154827     -0.366995
# 75%              0.0     0.930851        0.865183      0.617788
# max              0.0     1.619346        1.833399      2.850715

# %% [markdown]
# ### Applying OneHotEncoding on Categorical Columns on X_test

# %%
X_test_cat_ohe = pd.DataFrame(encoder.transform(X_test_cat),
                              columns = encoder.get_feature_names_out(X_test_cat.columns),
                              index = X_test_cat.index) 

X_test_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 2816          0.0          1.0             0.0               1.0
# 1321          1.0          1.0             1.0               1.0
# 1455          0.0          1.0             0.0               1.0
# 6526          1.0          0.0             1.0               1.0
# 2227          1.0          1.0             1.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 2816                             0.0                1.0
# 1321                             0.0                0.0
# 1455                             0.0                1.0
# 6526                             0.0                1.0
# 2227                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 2816                          1.0                 0.0
# 1321                          0.0                 0.0
# 1455                          1.0                 0.0
# ...

# %%
X_test_cat_ohe.describe()
# Out:
#        gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# count  1476.000000  1476.000000     1476.000000       1476.000000
# mean      0.503388     0.482385        0.336043          0.895664
# std       0.500158     0.499859        0.472514          0.305800
# min       0.000000     0.000000        0.000000          0.000000
# 25%       0.000000     0.000000        0.000000          1.000000
# 50%       1.000000     0.000000        0.000000          1.000000
# 75%       1.000000     1.000000        1.000000          1.000000
# max       1.000000     1.000000        1.000000          1.000000
#
#        MultipleLines_No phone service  MultipleLines_Yes  \
# count                     1476.000000        1476.000000
# mean                         0.104336           0.402439
# std                          0.305800           0.490556
# min                          0.000000           0.000000
# 25%                          0.000000           0.000000
# ...

# %% [markdown]
# ### Concatinating the Encoded Categorical Features and Rescaled Numerical Features for X_test

# %%
X_test_transformed = pd.concat([X_test_num_rescaled,X_test_cat_ohe],axis = 1)

X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 2816            0.0  1.619346        1.582150      2.687360          0.0
# 1321            0.0  1.133350        0.137471      0.788074          1.0
# 1455            0.0  0.161358        1.466444      0.745980          0.0
# 6526            0.0  0.687854        1.286272      1.299722          1.0
# 2227            0.0  1.052350       -1.393162     -0.475860          1.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 2816          1.0             0.0               1.0
# 1321          1.0             1.0               1.0
# 1455          1.0             0.0               1.0
# 6526          0.0             1.0               1.0
# 2227          1.0             1.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 2816                             0.0                1.0  ...
# 1321                             0.0                0.0  ...
# ...

# %% [markdown]
# ### Problem:
# - Target variable: Churn
# - Historical available ? Yes
# - Type: Supervised Learning
# - Task : Classification

# %% [markdown]
# ### Step-6: Model Training Phase - Use all the algorithms mentioned below to train separate models:
# - Logistic Regression
# - KNN
# - Support Vector Machines
# - Decision Trees
# - Navie Bayes
# - Random Forest
# - Ada Booster
# - GBDT
# ### Step - 7: Predict and evaluate each model separately using the correct evaluation metric. Use metrics.accuracy_score(actual, predict).
# ### Step - 8: Display a plot which shows all the algorithms applied along with the accuracies achieved

# %% [markdown]
# ### Building a model:
# #### Training- Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed,y_train)
y_test_predict = classifier.predict(X_test_transformed)
from sklearn.metrics import accuracy_score

a = accuracy_score(y_test, y_test_predict)
a
# Out:
# 0.809620596205962

# %% [markdown]
# ### Training- KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
b = accuracy_score(y_test, y_test_predict)
b
# Out:
# 0.7845528455284553

# %% [markdown]
# ### Training- Support Vector Classifier

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
c = accuracy_score(y_test, y_test_predict)
c
# Out:
# 0.8089430894308943

# %% [markdown]
# ### Training- Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
d = accuracy_score(y_test, y_test_predict)
d
# Out:
# 0.7459349593495935

# %% [markdown]
# ### Training _ Navie Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
e = accuracy_score(y_test, y_test_predict)
e
# Out:
# 0.6754742547425474

# %% [markdown]
# ### Training- Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
f = accuracy_score(y_test, y_test_predict)
f
# Out:
# 0.806910569105691

# %% [markdown]
# ### Training- Adaptive Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
classifier = AdaBoostClassifier()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
g = accuracy_score(y_test, y_test_predict)
g
# Out:
# 0.8136856368563685

# %% [markdown]
# ### Training - Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier=GradientBoostingClassifier()
classifier.fit(X_train_transformed,y_train)

y_test_predict = classifier.predict(X_test_transformed)

from sklearn.metrics import accuracy_score
h = accuracy_score(y_test, y_test_predict)
h
# Out:
# 0.8055555555555556

# %%
import pandas as pd
Data = {'Algorithms':['LogisticRegression','KNN Classifier','Support Vector Classifier',' Decision Trees Classifier','Navie Bayes Classifier','Random Forest Classifier',
                           'Adaptive Boost Classifier','Gradient Boosting Classifier'],'Accuracy_Score': [a,b,c,d,e,f,g,h]}

d = pd.DataFrame(Data)
d
# Out:
#                      Algorithms  Accuracy_Score
# 0            LogisticRegression        0.809621
# 1                KNN Classifier        0.784553
# 2     Support Vector Classifier        0.808943
# 3     Decision Trees Classifier        0.745935
# 4        Navie Bayes Classifier        0.675474
# 5      Random Forest Classifier        0.806911
# 6     Adaptive Boost Classifier        0.813686
# 7  Gradient Boosting Classifier        0.805556

# %%
sns.barplot(y = d.Algorithms, x = d.Accuracy_Score)
# Out:
# <AxesSubplot:xlabel='Accuracy_Score', ylabel='Algorithms'>

# %% [markdown]
# ### Write your conclusion on the best algorithm for Churn Prediction.

# %% [markdown]
# ### Conclusion
#
# - Logistic Regression algorithm is the best model for Churn prediction
# - Compare to other algorithm accuracy_score(y_test, y_test_predict) of Logistic Regression there is a maximum accuracy with 80.9%.
